# %% [markdown]
# # Data Wrangling
#
# * [1. Loading Data](#loading)
# * [2. Data Cleaning](#data-cleaning)
#     * [2.1 Missing Values](#missing)
#     * [2.2 Duplicates](#duplicates)
#     * [2.3 Illogical Data](#illogical)
#         * [2.3.1 Sets of Books](#sets)
#     * [2.4 Book Formats](#formats)
# * [3. Adding Categories](#categories)
#     * [3.1 Book Length](#length)
#     * [3.2 Good or Bad Book](#goodbad)

# %% [markdown]
# # 1. Loading Data <a name='loading'></a>

# %%
#Load the relevant libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the Kaggle goodreads dataset obtained from
#https://www.kaggle.com/meetnaren/goodreads-best-books
#that's based on the Goodreads list of best books ever: https://www.goodreads.com/list/show/1.Best_Books_Ever
best_books = pd.read_csv('best_books.csv')

# %%
best_books.head()
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling|Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
#
#                                            book_desc  \
# 0  Winning will make you famous. Losing means cer...
# 1  There is a door at the end of a silent corrido...
# 2  The unforgettable novel of a childhood in a sl...
# 3  «È cosa ormai risaputa che a uno scapolo in po...
# 4  About three things I was absolutely positive.F...
#
#                          book_edition book_format    book_isbn book_pages  \
# 0                                 NaN   Hardcover  9.78044E+12  374 pages
# 1                          US Edition   Paperback  9.78044E+12  870 pages
# 2                    50th Anniversary   Paperback  9.78006E+12  324 pages
# 3  Modern Library Classics, USA / CAN   Paperback  9.78068E+12  279 pages
# 4                                 NaN   Paperback  9.78032E+12  498 pages
#
#    book_rating  book_rating_count  book_review_count  \
# 0         4.33            5519135             160706
# 1         4.48            2041594              33264
# 2         4.27            3745197              79450
# 3         4.25            2453620              54322
# 4         3.58            4281268              97991
#
#                                   book_title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                               genres  \
# 0  Young Adult|Fiction|Science Fiction|Dystopia|F...
# 1                        Fantasy|Young Adult|Fiction
# 2  Classics|Fiction|Historical|Historical Fiction...
# 3                           Classics|Fiction|Romance
# 4  Young Adult|Fantasy|Romance|Paranormal|Vampire...
#
#                                            image_url
# 0  https://images.gr-assets.com/books/1447303603l...
# 1  https://images.gr-assets.com/books/1255614970l...
# 2  https://images.gr-assets.com/books/1361975680l...
# 3  https://images.gr-assets.com/books/1320399351l...
# 4  https://images.gr-assets.com/books/1361039443l...

# %%
best_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54301 entries, 0 to 54300
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   book_authors       54301 non-null  object
#  1   book_desc          52970 non-null  object
#  2   book_edition       5453 non-null   object
#  3   book_format        52645 non-null  object
#  4   book_isbn          41435 non-null  object
#  5   book_pages         51779 non-null  object
#  6   book_rating        54301 non-null  float64
#  7   book_rating_count  54301 non-null  int64
#  8   book_review_count  54301 non-null  int64
#  9   book_title         54301 non-null  object
#  10  genres             51059 non-null  object
#  11  image_url          53618 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 5.0+ MB

# %%
#Let's first create a copy to keep the original intact
books = best_books.copy(deep=True)

# %% [markdown]
# Let's quickly rename the column names to be more concise.

# %%
#Strip the 'book_' from the column names
books.columns = [col_name.lstrip('book_') if ('book_' in col_name) else col_name for col_name in best_books.columns]

# %% [markdown]
# # 2. Data Cleaning <a name='data-cleaning'></a>
#
# This section will first cover how missing values, outliers, duplicates, or illogical data will be dealt with. Then, I'll take a look at cleaning up some of the data so that it's easier to work with later.
#
# Before I look at any missing values, I'm going to also remove the unnecessary "pages" unit from the `pages` column so that the values can be numeric.

# %%
#Remove the unit from the pages values
books.pages = books.pages.str.rstrip(' pages')

#Convert the pages column to numbers
books.pages = pd.to_numeric(books.pages)

# %%
books.describe()
# Out:
#               pages        rating  rating_count  review_count
# count  51779.000000  54301.000000  5.430100e+04   54301.00000
# mean     337.662836      4.020027  4.350449e+04    2011.60218
# std      259.533005      0.362100  2.126572e+05    7627.07287
# min        0.000000      0.000000  0.000000e+00       0.00000
# 25%      216.000000      3.830000  4.070000e+02      35.00000
# 50%      310.000000      4.030000  2.811000e+03     188.00000
# 75%      400.000000      4.220000  1.274500e+04     822.00000
# max    14777.000000      5.000000  5.588580e+06  160776.00000

# %% [markdown]
# The ISBN feature of this dataset is not very useful since it's in scientific notation and half of the ISBN is lost to the notation. Therefore, I'll be removing it with the `image_url` column since I won't be using that feature.

# %%
#Delete the isbn and image_url columns
books.drop(columns=['isbn', 'image_url'], inplace=True)

# %% [markdown]
# ## 2.1 Missing Values <a name='missing'></a>
#
# I'll be looking at how to handle the missing values in the dataset.

# %%
books.isna().sum()
# Out:
# authors             0
# desc             1331
# edition         48848
# format           1656
# pages            2522
# rating              0
# rating_count        0
# review_count        0
# title               0
# genres           3242
# dtype: int64

# %% [markdown]
# Let's look at some of the missing values for genres and page numbers, before we tackle the books with 0 ratings/pages/etc.

# %%
books[books.genres.isnull()==True]
# Out:
#                           authors  \
# 260              سید مرتضی مصطفوی
# 716              سید مرتضی مصطفوی
# 1421             سید مرتضی مصطفوی
# 1928                    أحمد مراد
# 1989          Christine M. Knight
# ...                           ...
# 54225  Chuck Rogers|Don Pendleton
# 54229               William Logan
# 54236                Chris Pepple
# 54259                 Jackie Budd
# 54290               WAKAKI Tamiki
#
#                                                     desc      edition  \
# 260    Mystical storyThe internal revolution of a wom...        فارسی
# 716    Philosophical story about human loneliness in ...          NaN
# 1421   رمان بلند "سیمای شکسته پدر سالار" که از  تعلیق...        فارسی
# 1928   "للمرة الثانية بعد "فيرتيجو" يتّخذ أحمد مراد م...          NaN
# 1989   “I’m not Mavis anymore.” For years, song bird ...          NaN
# ...                                                  ...          ...
# 54225  When American military personnel are found beh...          NaN
# 54229  Talented William Logan, though he hails from D...          NaN
# 54236                                                NaN          NaN
# 54259  Lively and wide-ranging text together with col...  Large Print
# 54290  Target Keima kali ini adalah tipe "adik kelas"...          NaN
#
#           format  pages  rating  rating_count  review_count  \
# 260        ebook  204.0    3.97           956           129
# 716          NaN   82.0    4.12           923           256
# 1421       ebook  367.0    3.55           722             7
# 1928   Paperback  389.0    4.07         48474          4239
# 1989   Paperback  304.0    4.59            39            34
# ...          ...    ...     ...           ...           ...
# 54225  Paperback  188.0    4.14            14             1
# 54229      ebook   12.0    2.67             6             1
# 54236  Paperback  120.0    5.00             1             0
# 54259  Paperback   64.0    3.67             3             2
# 54290  Paperback  200.0    4.63             8             0
#
#                                                    title genres
# 260                                   زندگی مه آلود پریا    NaN
# 716                                      گم شده ای در مه    NaN
# 1421                               سیمای شکسته پدر سالار    NaN
# 1928                                          تراب الماس    NaN
# 1989                     Song Bird: Matters of the Heart    NaN
# ...                                                  ...    ...
# 54225                                      Crisis Nation    NaN
# 54229                                                Mex    NaN
# 54236        Look to See Me: A Collection of Reflections    NaN
# 54259                                The World of Horses    NaN
# 54290  The World God Only Knows vol. 06 (The World Go...    NaN
#
# [3242 rows x 10 columns]

# %%
books[books.pages.isnull()==True]
# Out:
#                             authors  \
# 1225               Gabrielle Estres
# 1296                     Tom Clancy
# 1392                 Roberta Pearce
# 1424   Robyn Mundell|Stephan Lacast
# 1787                 Chris A. Jones
# ...                             ...
# 54284                 Tamiki Wakaki
# 54285                 Tamiki Wakaki
# 54286                 Tamiki Wakaki
# 54288                 Tamiki Wakaki
# 54298                 Howard Megdal
#
#                                                     desc   edition  \
# 1225   “A captivating tale of love, power and betraya...       NaN
# 1296   2 cassettes / 2 hoursRead by F. Murray Abraham...  Abridged
# 1392   After an impoverished and indigent childhood, ...       NaN
# 1424   One teen’s incredible journey may just blow hi...       NaN
# 1787   Mankind had spent decades trying to overcome a...       NaN
# ...                                                  ...       ...
# 54284                                                NaN       NaN
# 54285                                                NaN       NaN
# 54286                                                NaN       NaN
# 54288                                                NaN       NaN
# 54298                                                NaN       NaN
#
#                format  pages  rating  rating_count  review_count  \
# 1225            ebook    NaN    4.79           331            16
# 1296   Audio Cassette    NaN    4.15         63105           956
# 1392            ebook    NaN    4.23           153            31
# 1424            ebook    NaN    4.27          1054           153
# 1787            ebook    NaN    4.14           521             1
# ...               ...    ...     ...           ...           ...
# 54284       Paperback    NaN    4.24           141             1
# 54285       Paperback    NaN    4.20           143             2
# 54286       Paperback    NaN    4.34           182             2
# 54288       Paperback    NaN    4.32           179             2
# 54298  Kindle Edition    NaN    3.66            32             3
#
#                                                    title  \
# 1225                                             Captive
# 1296                                    Red Storm Rising
# 1392                                A Bird Without Wings
# 1424                                         Brainwalker
# 1787                        Reversione: Reset the Future
# ...                                                  ...
# 54284                        The World God Only Knows 17
# 54285                        The World God Only Knows 18
# 54286                        The World God Only Knows 11
# 54288                        The World God Only Knows 12
# 54298  Wilpon's Folly - The Story of a Man, His Fortu...
#
#                                                   genres
# 1225   Romance|Fantasy|Romance|Paranormal Romance|Rom...
# 1296           Fiction|Thriller|War|Military Fiction|War
# 1392   Romance|Romance|Contemporary Romance|Contemporary
# 1424   Young Adult|Fantasy|Fiction|Adventure|New Adul...
# 1787   Young Adult|Adventure|Mystery|Fantasy|New Adul...
# ...                                                  ...
# 54284                  Sequential Art|Manga|Comics Manga
# 54285                  Sequential Art|Manga|Comics Manga
# 54286                  Sequential Art|Manga|Comics Manga
# 54288   Sequential Art|Manga|Comics Manga|Sequential Art
# 54298                          Sports|Baseball|Abandoned
#
# [2522 rows x 10 columns]

# %% [markdown]
# I'll be removing the ones with missing genres/pages, since those will be the primary features I'll be looking at and exploring. Additionally, it looks like some books have not only genres/pages missing but some also have multiple missing values; let's remove the ones with more than 3 missing features.

# %%
#Remove rows with more than 3 missing features
books.dropna(axis=0, thresh=9, inplace=True)

# %%
#Remove rows with missing pages or missing genres
books.dropna(axis=0, subset=['pages', 'genres'], how='any', inplace=True)

# %% [markdown]
# Now I'll be filling in the missing values as 'missing.'

# %%
#Fill the missing values as 'missing'
books.fillna('Missing', inplace=True)

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47760 entries, 0 to 54300
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   authors       47760 non-null  object
#  1   desc          47760 non-null  object
#  2   edition       47760 non-null  object
#  3   format        47760 non-null  object
#  4   pages         47760 non-null  float64
#  5   rating        47760 non-null  float64
#  6   rating_count  47760 non-null  int64
#  7   review_count  47760 non-null  int64
#  8   title         47760 non-null  object
#  9   genres        47760 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 4.0+ MB

# %% [markdown]
# About 5k books was deleted, but there still is a good amount of books remaining. Now to really look at some the actual values.

# %% [markdown]
# ## 2.2 Duplicates <a name='duplicates'></a>
#
# First I'll explore to see if there are any duplicates, and keep only one of the duplicates.

# %%
books[books.duplicated(keep='first')]
# Out:
#                  authors                                               desc  \
# 6467     Kirsten Fullmer  Lizzie gave up her stressful job in Boston to ...
# 10353      Rahiem Brooks  "Brooks’s clunky first Naim Butler contemporar...
# 24460   Frances Hardinge  This is the story of a bear-hearted girl . . ....
# 29507  Annemarie O'Brien  Young Lara is being groomed in the family trad...
# 37591      Rhonda Patton  Ted and Raymond go to Africa. They find great ...
# 47849        Chloe Neill  Since Merit was turned into a vampire, and the...
#
#        edition          format  pages  rating  rating_count  review_count  \
# 6467   Missing  Kindle Edition  297.0    4.25           630            16
# 10353  Missing       Paperback  278.0    4.70            30            18
# 24460  Missing       Hardcover  416.0    4.09          2773           532
# 29507  Missing       Hardcover  208.0    3.99           630           126
# 37591  Missing       Paperback   40.0    4.61            66            13
# 47849  Missing       Paperback  350.0    4.20         11220           676
#
#                                      title  \
# 6467                 Hometown Girl Forever
# 10353                   A Butler Christmas
# 24460                 A Skinful of Shadows
# 29507                          Lara's Gift
# 37591  African Safari with Ted and Raymond
# 47849                          Wild Things
#
#                                                   genres
# 6467   Young Adult|Contemporary|New Adult|Romance|Lov...
# 10353                  Romance|Holiday|Holiday|Christmas
# 24460  Fantasy|Historical|Historical Fiction|Young Ad...
# 29507  Historical|Historical Fiction|Childrens|Middle...
# 37591                                          Childrens
# 47849  Fantasy|Urban Fantasy|Paranormal|Vampires|Fant...

# %%
books.title.value_counts()
# Out:
# 1984                                                                  16
# Selected Poems                                                        14
# The Hobbit                                                            13
# American Gods                                                         13
# A Christmas Carol                                                     12
#                                                                       ..
# Welcome to Hard Times                                                  1
# For Women Only: What You Need to Know about the Inner Lives of Men     1
# Histoires inédites du Petit Nicolas Volume 2                           1
# Lost in Learning: The Art of Discovery                                 1
# Death in Venice and Seven Other Stories                                1
# Name: title, Length: 42424, dtype: int64

# %%
books[books.title=='1984']
# Out:
#                                            authors  \
# 100                      George Orwell|Erich Fromm
# 5161            George Orwell|Peter Hobley Davison
# 7348                                 George Orwell
# 9987                                 George Orwell
# 13992  George Orwell|Alexandre Hubner|Heloísa Jahn
# 19074                    George Orwell|أنور الشامي
# 21486                                George Orwell
# 21918                                George Orwell
# 22072               George Orwell|Amélie Audiberti
# 22093                                George Orwell
# 22280                    George Orwell|Celâl Üster
# 31244                                George Orwell
# 32305                George Orwell|Ana Luísa Faria
# 43919                                George Orwell
# 44664                    George Orwell|أنور الشامي
# 48111                                George Orwell
#
#                                                     desc  \
# 100    Among the seminal texts of the 20th century, N...
# 5161   'It was a bright cold day in April, and the cl...
# 7348   Among the seminal texts of the 20th century, N...
# 9987   Among the seminal texts of the 20th century, N...
# 13992  1984 é uma das obras mais influentes do século...
# 19074  على مدى سنوات طويلة ظلت رواية 1984 لجورج اوروي...
# 21486  Nineteen Eighty-Four revealed George Orwell as...
# 21918  1984 oferece hoje uma descrição quase realista...
# 22072  De tous les carrefours important, le visage à ...
# 22093  Sepanjang hidupnya, Winston berusaha menjadi w...
# 22280  Parti’nin dünya görüşü, onu hiç anlayamayan in...
# 31244  1984 reduce a su esencia luchas humanas en las...
# 32305  Segundo Orwell, 1984 é uma sátira, onde aliás ...
# 43919  Alternate cover edition for ISBNs 0451524934 /...
# 44664  على مدى سنوات طويلة، ظلت رواية "1984" لجورج أو...
# 48111  Among the seminal texts of the 20th century, N...
#
#                         edition                 format  pages  rating  \
# 100             Signet Classics  Mass Market Paperback  328.0    4.16
# 5161                    Missing              Paperback  326.0    4.16
# 7348                    Missing         Kindle Edition  237.0    4.16
# 9987                    Missing         Kindle Edition  237.0    4.16
# 13992                   Missing              Paperback  416.0    4.16
# 19074                   الثالثة              Paperback  352.0    4.16
# 21486                   Missing              Hardcover  326.0    4.16
# 21918                   Missing              Paperback  327.0    4.16
# 22072                Folio #822  Mass Market Paperback  448.0    4.16
# 22093                   Missing              Paperback  408.0    4.16
# 22280                   Missing              Paperback  352.0    4.16
# 31244                   Missing              Paperback  254.0    4.16
# 32305  Colecção Mil folhas, #25              Hardcover  320.0    4.16
# 43919                   Missing  Mass Market Paperback  268.0    4.16
# 44664                   Missing              Paperback  352.0    4.16
# 48111                   Missing         Kindle Edition  322.0    4.16
#
#        rating_count  review_count title  \
# 100         2420816         53773  1984
# 5161        2421887         53794  1984
# 7348        2421777         53793  1984
# 9987        2422197         53801  1984
# 13992       2422432         53809  1984
# 19074       2422645         53814  1984
# 21486       2422732         53817  1984
# 21918       2422748         53817  1984
# 22072       2422763         53817  1984
# 22093       2422763         53817  1984
# 22280       2422763         53817  1984
# 31244       2423091         53821  1984
# 32305       2423145         53823  1984
# 43919       2423511         53830  1984
# 44664       2423524         53830  1984
# 48111       2423619         53833  1984
#
#                                                   genres
# 100    Classics|Fiction|Science Fiction|Science Ficti...
# 5161   Classics|Fiction|Science Fiction|Science Ficti...
# 7348   Classics|Fiction|Science Fiction|Science Ficti...
# 9987   Classics|Fiction|Science Fiction|Science Ficti...
# 13992  Classics|Fiction|Science Fiction|Science Ficti...
# 19074  Classics|Fiction|Science Fiction|Science Ficti...
# 21486  Classics|Fiction|Science Fiction|Science Ficti...
# 21918  Classics|Fiction|Science Fiction|Science Ficti...
# 22072  Classics|Fiction|Science Fiction|Science Ficti...
# 22093  Classics|Fiction|Science Fiction|Science Ficti...
# 22280  Classics|Fiction|Science Fiction|Science Ficti...
# 31244  Classics|Fiction|Science Fiction|Science Ficti...
# 32305  Classics|Fiction|Science Fiction|Science Ficti...
# 43919  Classics|Fiction|Science Fiction|Science Ficti...
# 44664  Classics|Fiction|Science Fiction|Science Ficti...
# 48111  Classics|Fiction|Science Fiction|Science Ficti...

# %% [markdown]
# Not only are there complete duplicates of entries, but it also looks like there are multiple of the same book with different formats and editions. From the latter, the pages seem more or less aligned with each other, and the ratings/counts are the same. So I'll be keeping the books with the most amount of ratings. This way, the complete duplicates are also filtered out.

# %%
#Keep the duplicates with the highest rating count
books = books.sort_values(['title', 'rating_count', 'review_count'], ascending=True).drop_duplicates(subset='title', keep='last')

# %%
books.title.value_counts()
# Out:
# Grief Girl: My True Story                                                                         1
# Demon Song                                                                                        1
# The Painted Veil                                                                                  1
# Life Studies                                                                                      1
# Fareler ve İnsanlar                                                                               1
#                                                                                                  ..
# The Pink Dress                                                                                    1
# Karamazov Kardeşler                                                                               1
# Creative Visualization: Use the Power of Your Imagination to Create What You Want in Your Life    1
# Al di qua del Paradiso                                                                            1
# Death in Venice and Seven Other Stories                                                           1
# Name: title, Length: 42424, dtype: int64

# %%
books[books.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [authors, desc, edition, format, pages, rating, rating_count, review_count, title, genres]
# Index: []

# %% [markdown]
# ## 2.3 Illogical Data <a name='illogical'></a>
#
# To look at the illogical data, or any data that doesn't really make sense with what it's supposed to be, I'm going to explore the actual values of the feature. Before that however, I'm going to remove all books with less than 100 ratings, since this would either encompass some "illogical" values or validate them, like the ones with a 0 rating or 0 pages. I would deem 100 ratings to be a reasonable minimum since the median of `rating_count` is 3763. I'm not considering the mean here since there are some books with an disproportionately large `rating_count`, which skews the mean.

# %%
#Remove the books with less than 100 ratings
books.drop(index=books[books.rating_count<100].index, inplace=True)

# %%
books.describe()
# Out:
#               pages        rating  rating_count   review_count
# count  38629.000000  38629.000000  3.862900e+04   38629.000000
# mean     346.600818      3.993088  3.455862e+04    1659.270936
# std      258.374482      0.277012  1.756206e+05    6289.348471
# min        0.000000      2.090000  1.000000e+02       0.000000
# 25%      226.000000      3.820000  1.138000e+03      81.000000
# 50%      320.000000      4.010000  4.146000e+03     269.000000
# 75%      406.000000      4.180000  1.429600e+04     905.000000
# max    14777.000000      4.890000  5.588580e+06  160776.000000

# %% [markdown]
# It seems odd that there are books with 0 pages and also those with more than 2000.

# %%
books[books.pages > 2000]
# Out:
#                                   authors  \
# 14080        Romain Rolland|م. ا. به‌آذین
# 21608  Cao Xueqin|Gladys Yang|Xianyi Yang
# 23569                  George R.R. Martin
# 1730                   George R.R. Martin
# 4349   K.A. Applegate|Katherine Applegate
# ...                                   ...
# 11334    شمس الدين الذهبي|حسان عبد المنان
# 20335                  Sayed Qutb|سيد قطب
# 49216   Abdul Rahman Munif|عبدالرحمن منيف
# 13275                         Ibn Khaldun
# 13555                 Mahmoud Dowlatabadi
#
#                                                     desc  \
# 14080  Complete in one volume:1. L'Aube ("Dawn", 1904...
# 21608  Also known as Hong Lou Meng, this is arguably ...
# 23569  George R.R. Martin's A Song of Ice and Fire is...
# 1730   For the first time, all five novels in the epi...
# 4349   Animorphs "RM" is an exciting series for young...
# ...                                                  ...
# 11334  كتاب سير أعلام النبلاء يعتبر من أمتع كتب الترا...
# 20335  راخواطر وانطباعات من فترة عاشها سيد قطب في ظلا...
# 49216  مدن الملح هي رواية عربية للروائي السعودي عبد ا...
# 13275  "The Muqaddimah," often translated as "Introdu...
# 13555  محمود دولت‌آبادی متولد ۱۳۱۹ اهل دولت آباد سبزو...
#
#                        edition                 format   pages  rating  \
# 14080                  Missing              Hardcover  2179.0    4.17
# 21608         4 volume box set              Paperback  2549.0    4.11
# 23569                  Missing              Paperback  5216.0    4.64
# 1730       Re-Packaged Edition  Mass Market Paperback  5216.0    4.64
# 4349                   Missing              Paperback  8245.0    4.34
# ...                        ...                    ...     ...     ...
# 11334                  Missing              Hardcover  4683.0    4.35
# 20335  First-time author notes              Hardcover  4012.0    4.52
# 49216                  Missing              Paperback  2345.0    4.33
# 13275                  Missing              Hardcover  3864.0    4.30
# 13555                  Missing              Hardcover  2837.0    4.29
#
#        rating_count  review_count                                 title  \
# 14080           650            45           (ژان کریستف (دورۀ چهار جلدی
# 21608          3173           263               A Dream of Red Mansions
# 23569         42043          1495  A Game of Thrones: The First 5 Books
# 1730          42029          1495                A Song of Ice and Fire
# 4349           3647           208                             Animorphs
# ...             ...           ...                                   ...
# 11334           453            32                     سير أعلام النبلاء
# 20335          3210           133                        في ظلال القرآن
# 49216           959           125                             مدن الملح
# 13275          3048           246                       مقدمة ابن خلدون
# 13555          2681           200                                 کلیدر
#
#                                                   genres
# 14080  Novels|Fiction|Cultural|France|Literature|Clas...
# 21608  Classics|Fiction|Cultural|China|Literature|His...
# 23569                                    Fantasy|Fiction
# 1730                                     Fantasy|Fiction
# 4349   Science Fiction|Childrens|Young Adult|Fiction|...
# ...                                                  ...
# 11334                           Biography|Religion|Islam
# 20335                            Religion|Islam|Religion
# 49216                                     Novels|Fiction
# 13275  Nonfiction|Sociology|Classics|Politics|History...
# 13555                                  Novels|Literature
#
# [90 rows x 10 columns]

# %%
books[books.pages == 0]
# Out:
#                          authors  \
# 25009          James L. Gillaspy
# 22603       Arthur R.G. Solmssen
# 47010  Jack Kilborn|Phil Gigante
# 38704                 NOT A BOOK
# 33835            Agatha Christie
# ...                          ...
# 45421                 Pet Torres
# 28817               Aaron Polson
# 15224               Craig Thomas
# 21469             P.G. Wodehouse
# 50862             Danielle Steel
#
#                                                     desc  edition  \
# 25009  The broadcast interview of a young computer pr...  Missing
# 22603  Berlín, 1922. Reina la confusión en la capital...  Missing
# 47010  WELCOME TO SAFE HAVEN, POPULATION 907...Nestle...  Missing
# 38704  In this presentation, Glenn Beck tells an audi...  Missing
# 33835                                            Missing  Box set
# ...                                                  ...      ...
# 45421  SYNOPSISValkyrie is a young girl who has been ...  Missing
# 28817  While cruising a dark country road late one Sa...  Missing
# 15224  An East German defector dies in a tragic accid...  Missing
# 21469  Table of ContentsList of Works by Genre and Ti...  Missing
# 50862  Against the backdrop of the Russian Revolution...  Missing
#
#                       format  pages  rating  rating_count  review_count  \
# 25009                   Nook    0.0    3.81           306            22
# 22603  Mass Market Paperback    0.0    3.91           292            18
# 47010               Audio CD    0.0    3.90          7982           957
# 38704               Audio CD    0.0    4.16           207            42
# 33835              Paperback    0.0    4.20           207            10
# ...                      ...    ...     ...           ...           ...
# 45421                   Nook    0.0    3.29           288            19
# 28817                   Nook    0.0    3.01           207            25
# 15224              Paperback    0.0    3.35           129             5
# 21469                  ebook    0.0    4.49           412            10
# 50862              Paperback    0.0    3.96         11951           389
#
#                                                    title  \
# 25009                                  A Larger Universe
# 22603                               A Princess in Berlin
# 47010                                             Afraid
# 38704                                 An Unlikely Mormon
# 33835  And Then There Were None/The Secret Adversary/...
# ...                                                  ...
# 45421                     Valkyrie: The Vampire Princess
# 28817                                We are the Monsters
# 15224                                            Wildcat
# 21469                           Works of P. G. Wodehouse
# 50862                                               Zoya
#
#                                                   genres
# 25009                            Science Fiction|Fiction
# 22603  Fiction|Romance|Historical|Historical Fiction|...
# 47010           Horror|Thriller|Fiction|Mystery|Suspense
# 38704  Nonfiction|Biography|Christianity|Lds|Religion...
# 33835                                  Mystery|Childrens
# ...                                                  ...
# 45421  Paranormal|Vampires|Young Adult|Fantasy|Supern...
# 28817                            Horror|Fiction|Suspense
# 15224                         Fiction|Thriller|Adventure
# 21469                Fiction|Humor|Classics|Humor|Comedy
# 50862  Romance|Fiction|Historical|Historical Fiction|...
#
# [125 rows x 10 columns]

# %% [markdown]
# Some books with 0 pages are sets of books, or audiobooks. I'm going to take a some time to clean up the formats before dealing with the pages.

# %%
books.loc[books.pages==0].format.value_counts(dropna=False)
# Out:
# Paperback                31
# ebook                    21
# Audio CD                 18
# Nook                     14
# Hardcover                13
# Audio                     8
# Audiobook                 6
# Audio Cassette            6
# Mass Market Paperback     4
# MP3 CD                    2
# Boxed Set                 1
# Board Book                1
# Name: format, dtype: int64

# %%
#Check the books dataframe to make sure it's still okay
books.head()
# Out:
#                               authors  \
# 28854  Julio Ortega|Jorge Luis Borges
# 36555        Sven Lindqvist|Joan Tate
# 3610                 Michael   Kramer
# 18919      Stephen King|Gönül Suveren
# 8901        Harlan Ellison|Rick Berry
#
#                                                     desc  edition  \
# 28854  De los muy pocos manuscritos que se conservan ...  Missing
# 36555  "Exterminate All the Brutes" is a searching ex...  Missing
# 3610   The formation of the English people starting w...  Missing
# 18919  Yıllar önce çocukluk kâbuslarına giren ‘O’ tüm...  Missing
# 8901   A rebel inhabits a world where conformity and ...  Missing
#
#                format  pages  rating  rating_count  review_count  \
# 28854       Paperback   13.0    4.31           124             6
# 36555       Paperback  179.0    4.15          1078            98
# 3610   Kindle Edition  239.0    4.29           299             2
# 18919       Paperback  441.0    4.22        612802         18309
# 8901        Hardcover   48.0    4.21          2347           129
#
#                                                    title  \
# 28854                    "El Aleph" de Jorge Luis Borges
# 36555  "Exterminate All the Brutes": One Man's Odysse...
# 3610                                       "Now What?!!"
# 18919                                                "O"
# 8901           "Repent, Harlequin!" Said the Ticktockman
#
#                                                   genres
# 28854                            Science Fiction Fantasy
# 36555          History|Nonfiction|Cultural|Africa|Travel
# 3610   Young Adult|Adventure|New Adult|Historical|His...
# 18919                    Horror|Fiction|Fantasy|Thriller
# 8901   Science Fiction|Short Stories|Fiction|Science ...

# %%
#Resort the index in the books dataframe
books = books.sort_index().reset_index(drop=True)

#Recheck the books dataframe
books.head()
# Out:
#                       authors  \
# 0  J.K. Rowling|Mary GrandPré
# 1              J.R.R. Tolkien
# 2               Douglas Adams
# 3            Shel Silverstein
# 4                   Dan Brown
#
#                                                 desc  \
# 0  There is a door at the end of a silent corrido...
# 1  لجزء الثالث من ملحمة جيه أر أر تولكين الرائعة ...
# 2  Seconds before the Earth is demolished to make...
# 3  "Once there was a tree...and she loved a littl...
# 4  An ingenious code hidden in the works of Leona...
#
#                          edition                 format   pages  rating  \
# 0                     US Edition              Paperback   870.0    4.48
# 1  Hobbit Movie Tie-in Boxed set  Mass Market Paperback  1728.0    4.59
# 2                        Missing              Paperback   193.0    4.21
# 3                        Missing              Hardcover    64.0    4.37
# 4                        Missing              Paperback   481.0    3.81
#
#    rating_count  review_count  \
# 0       2041594         33264
# 1         99793          1652
# 2       1155911         23919
# 3        789681         15694
# 4       1668594         43699
#
#                                                title  \
# 0          Harry Potter and the Order of the Phoenix
# 1  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 2               The Hitchhiker's Guide to the Galaxy
# 3                                    The Giving Tree
# 4                                  The Da Vinci Code
#
#                                               genres
# 0                        Fantasy|Young Adult|Fiction
# 1                           Fantasy|Fiction|Classics
# 2     Science Fiction|Fiction|Humor|Fantasy|Classics
# 3  Childrens|Childrens|Picture Books|Classics|Fic...
# 4                           Fiction|Mystery|Thriller

# %% [markdown]
# ### 2.2.1. Sets of Books <a name='sets'></a>
#
# Since I want to look at only individual books, I'll be dropping all sets or collections of books that I can find.

# %%
#Create regex pattern to search for chronicles, set(s), collection(s) in the title
pat = r"\bchronicles\b|\bsets*\b|\bcollections*\b"

#Create new dataframe based on the regex search
book_sets = books.loc[books['title'].astype('str').str.contains(pat, regex=True, case=False)]

# %%
#Manually add the titles collected by regex that aren't sets
non_sets = ['...And the Truth Shall Set You Free', 'A Collection of Essays', 'A Gown of Spanish Lace (The Janette Oke Collection)', 'Blood Borne (Cathedral Chronicles, #1)', 'Burma Chronicles', 'Chronicles of Avonlea',
 'Chronicles, Volume One', 'Deep Down Dark: The Untold Stories of 33 Men Buried in a Chilean Mine, and the Miracle That Set Them Free', "Disney's Mulan Classic Storybook (The Mouse Works Classics Collection)", 
 "Disney's Storybook Collection", 'Go Set a Watchman', 'Imitatore (The Donna Chronicles #1)', 'I Hate Myselfie: A Collection of Essays', 'Indian Creek Chronicles: A Winter Alone in the Wilderness', 'Invisible Collection',
 'It Gets Worse: A Collection of Essays', 'Jerusalem: Chronicles from the Holy City', "LZ-'75: The Lost Chronicles of Led Zeppelin's 1975 American Tour", 'Lies Young Women Believe Companion Guide: And the Truth That Sets Them Free',
 'New England Witch Chronicles', 'Miz Lil: And the Chronicles of Grace', 'No Wonder They Call Him the Savior: Chronicles of the Cross', 'Piano/Vocal/Guitar Sheet Music: The Chronicles of Narnia: The Lion, the Witch and The Wardrobe',
 'Rain & Fire: A Guide to the Last Dragon Chronicles', 'Set Me Free', 'Set This House in Order', 'Set in Darkness','Set in Stone', 'Sheet Music: The Chronicles of Narnia - Prince Caspian', "The Atheist's Bible: An Illustrious Collection of Irreverent Thoughts",
 'The Andalite Chronicles', 'The Bane Chronicles', 'The Batman Chronicles, Vol. 1', 'The Black River Chronicles: Level One', 'The Christmas Chronicles: The Legend of Santa Claus', 'The Chronicles of Audy: 4R', 'The Chronicles of Faerie',
 'The Chronicles of Harris Burdick: 14 Amazing Authors Tell the Tales', 'The Chronicles of Pern: First Fall', 'The Chronicles of Spiderwick: A Grand Tour of the Enchanted World, Navigated by Thimbletack', 'The Complete Chronicles of Conan',
 'The Collection', 'The Curiosities: A Collection of Stories', 'The Cupid Chronicles', 'The Dodgeball Chronicles', 'The Edge Chronicles 10: The Immortals: The Book of Nate', 'The Edge Chronicles 1: The  Curse of the Gloamglozer: First Book of Quint',
 'The Edge Chronicles 2: The Winter Knights: Second Book of Quint', 'The Edge Chronicles 3: The Clash of the Sky Galleons: Third Book of Quint', 'The Edge Chronicles 5: Stormchaser: Second Book of Twig', 'The Edge Chronicles 6: Midnight Over Sanctaphrax: Third Book of Twig',
 'The Edge Chronicles 7: The Last of the Sky Pirates: First Book of Rook', 'The Edge Chronicles 8: Vox: Second Book of Rook', 'The Edge Chronicles Maps',  'The First Chronicles of Druss the Legend', 'The Fry Chronicles', 'The Immortal Collection', 'The Ivy Chronicles',
 'The Kane Chronicles Survival Guide', 'The Land That Time Forgot Collection', 'The Last War: A World Set Free', 'The Martian Chronicles', 'The Ring Sets Out','The Rising Dark: A Darkest Minds Collection', 'The Set Up', 'The Soul of Rumi: A New Collection of Ecstatic Poems',
 'The Spiderwick Chronicles Movie : The Movie Storybook', 'The Stalker Chronicles', 'The Superman Chronicles, Vol. 1', 'The Travelling Cat Chronicles', 'The Valley of Vision: A Collection of Puritan Prayers and Devotions', 'The Works of William Wordsworth (Wordsworth Collection)',
 'The Zombie Chronicles', 'To Draw Closer To God: A Collection Of Discourses', 'Tortall and Other Lands: A Collection of Tales', 'When I Was a Slave: Memoirs from the Slave Narrative Collection', 'Van Laven Chronicles: Throne of Novoxos', 'Wormwood: A Collection of Short Stories',
 'Zen Flesh, Zen Bones: A Collection of Zen and Pre-Zen Writings']

#Update book_sets to exclude the non_sets
book_sets = book_sets.loc[~book_sets.title.isin(non_sets)]

# %%
#Ignore all jupyter warnings
import warnings
warnings.filterwarnings('ignore')

#Create list where edition indicates sets
ed_sets = books.loc[books.edition.astype('str').str.contains(r"\bBox(ed)*\b|\bSets*\b", regex=True, case=False)]

# %%
#Join the two sets together
book_sets = book_sets.append(ed_sets)

# %%
#Keep only the rows not in the book_sets dataframe
books = pd.merge(books, book_sets, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)

# %%
books.shape
# Out:
# (38420, 10)

# %%
#Create list of indices with boxed set formats that will be dropped
to_drop = books[(books.format=='Boxed Set') | (books.format=='Box Set')].index

#Drop the boxed sets formats
books.drop(index=to_drop, inplace=True)

# %%
#Resort the index in the books dataframe
books = books.sort_index().reset_index(drop=True)

#Recheck the books dataframe
books.head()
# Out:
#                                      authors  \
# 0                 J.K. Rowling|Mary GrandPré
# 1                              Douglas Adams
# 2                           Shel Silverstein
# 3                                  Dan Brown
# 4  Lewis Carroll|John Tenniel|Martin Gardner
#
#                                                 desc     edition  \
# 0  There is a door at the end of a silent corrido...  US Edition
# 1  Seconds before the Earth is demolished to make...     Missing
# 2  "Once there was a tree...and she loved a littl...     Missing
# 3  An ingenious code hidden in the works of Leona...     Missing
# 4  " I can't explain myself, I'm afraid, sir," sa...     Missing
#
#                   format  pages  rating  rating_count  review_count  \
# 0              Paperback  870.0    4.48       2041594         33264
# 1              Paperback  193.0    4.21       1155911         23919
# 2              Hardcover   64.0    4.37        789681         15694
# 3              Paperback  481.0    3.81       1668594         43699
# 4  Mass Market Paperback  239.0    4.07        411153          9166
#
#                                                title  \
# 0          Harry Potter and the Order of the Phoenix
# 1               The Hitchhiker's Guide to the Galaxy
# 2                                    The Giving Tree
# 3                                  The Da Vinci Code
# 4  Alice's Adventures in Wonderland & Through the...
#
#                                               genres
# 0                        Fantasy|Young Adult|Fiction
# 1     Science Fiction|Fiction|Humor|Fantasy|Classics
# 2  Childrens|Childrens|Picture Books|Classics|Fic...
# 3                           Fiction|Mystery|Thriller
# 4                 Classics|Fantasy|Fiction|Childrens

# %% [markdown]
# ## 2.4 Book Formats <a name='formats'></a>
#
# To deal with all the different formats, I'm going to be organizing them into 5 main categories (not counting the missing values):
# 1. Paperback
# 2. Hardcover
# 3. Audio
# 4. Digital
# 5. Other

# %%
#Add indvidual formats that mean paperback
paper = ['Capa Mole', 'capa mole', 'Softcover', 'Spiral-bound','Capa mole - 15,5 x 23 x 2cm', 'Poche', 'Broché', 'broché', 'Capa comum', 'Bìa mềm', 'Broschiert', 'Tapa blanda', 'Brossura', 'pocket', '文庫', 'Taschenbuch', 'Bolsillo','Pasta blanda','']

#Add indvidual formats that mean hardcoverb
hard = ['Capa Dura','Leather Bound','Bonded Leather','Imitation Leather', 'Capa dura','Board Book','Board book', 'Board', 'Tapa dura con sobrecubierta', 'Kovakantinen', 'Innbundet']

#Add indvidual formats that suggest audio
audio = ['Podcast','CD-ROM', 'MP3 CD','Podiobook']
             
#Add indvidual formats that suggest digital
digital = ['ebook','Nook','PDF ', 'web','Wattpad']

#Create an empty list for other formats
other = []

#Iterate over all unique formats
for fmt in books.format.unique():
    #First check whether the format is already in one of the manually made lists
    if ((fmt not in paper) & (fmt not in hard) & (fmt not in audio) & (fmt not in digital)):
        #Add the formats in the appropriate category
        if 'paper' in fmt.lower():
            paper.append(fmt)
        elif 'hard' in fmt.lower():
            hard.append(fmt)
        elif 'audio' in fmt.lower():
            audio.append(fmt)
        elif 'kindle' in fmt.lower():
            digital.append(fmt)
        elif 'online' in fmt.lower():
            digital.append(fmt)
        elif 'digital' in fmt.lower():
            digital.append(fmt)
        #Add all others into  the other category
        elif 'Missing' not in fmt:
            other.append(fmt)

# %%
#Replace all those in list with the corresponding format category
books.format.replace(paper, 'Paperback', inplace=True)
books.format.replace(hard, 'Hardcover', inplace=True)
books.format.replace(audio, 'Audio', inplace=True)
books.format.replace(digital, 'Digital', inplace=True)
books.format.replace(other, 'Other', inplace=True)

# %%
books.format.unique()
# Out:
# array(['Paperback', 'Hardcover', 'Digital', 'Audio', 'Other', 'Missing'],
#       dtype=object)

# %% [markdown]
# ### Book Edition
#
# There are a lot of variations with first editions, which looks like the biggest portion, outside of the missing values. As such, I'll replace all edition values as 'First' or 'Other Edition', and create a separate `missing_ed` feature.

# %%
#Create missing_ed feature indicating if edition value is missing
books.loc[books.edition=='Missing','missing_ed']=1

#Fill the rest with 0
books.missing_ed.fillna(0, inplace=True)

# %%
books.edition.value_counts().head(20)
# Out:
# Missing                    34738
# First Edition                298
# 1st Edition                  249
# 1st edition                  102
# 1st                           73
# Second Edition                65
# الطبعة الأولى                 62
# Large Print                   59
# Oxford World's Classics       54
# 1                             50
# First                         47
# Penguin Classics              43
# 2nd Edition                   39
# Omnibus                       32
# Unabridged                    32
# UK                            30
# Revised Edition               24
# Penguin Modern Classics       24
# Trade                         23
# Abridged                      23
# Name: edition, dtype: int64

# %%
#Create manual list for first edition variations
first = ['First Edition', '1st Edition', '1st edition', '1st', 'الطبعة الأولى']

#Iterate over all unique formats
for ed in books.edition.unique():
    #First check whether the format is already in one of the manually made lists
    if (ed not in first):
        #Add the formats in the appropriate category
        if '1st' in ed.lower():
            first.append(ed)
        elif 'first' in ed.lower():
            first.append(ed)

# %%
first
# Out:
# ['First Edition',
#  '1st Edition',
#  '1st edition',
#  '1st',
#  'الطبعة الأولى',
#  'First Scholastic Trade Paperback Edition',
#  'First',
#  'First US Edition',
#  'First Touchstone Edition 2003',
#  'First Trade Paperback Edition',
#  'First edition',
#  "First St. Martin's Griffin Edition",
#  'First edition of this translation',
#  'US First Edition',
#  'First Vintage Edition',
#  '1st US Edition',
#  '1st Perennial Classics Edition',
#  '2000 Reprint (1st edition in Penguin 1945)',
#  'First Signet Classic Printing (Lingeman Introduction)',
#  'first print',
#  'Hyperion, First Edition',
#  'First Anchor Books edition (w/new Afterword)',
#  '1st Kindle Edition',
#  'First Vintage International edition',
#  'first',
#  'First American Edition',
#  'First Signet Edition',
#  'First Vintage Contemporaries Edition',
#  'First Mass Market Edition',
#  'First Touchstone Edition',
#  '1st Scribner trade paperback edition',
#  'First Knopf Trade Paperback Edition',
#  'First Broadway Paperback Edition',
#  '1st  Edition',
#  'First Edition (US / CAN)',
#  'First Thus edition',
#  'First Vintage International Open-Market Edition',
#  'First Edition (out of print)',
#  '1st Edition ',
#  'First Mariner Books edition',
#  '1st Science Fiction Book Club Edition',
#  'First Signet Classic Printing',
#  'First Edition, First Printing',
#  'First Broadway Books trade paperback edition',
#  'First American Paperback Edition',
#  'First Vintage International Edition',
#  'First mass market edition',
#  'First Harvest edition',
#  'First Trade',
#  'First Paperback Edition',
#  'First Riverhead trade paperback edition',
#  '1st edition and Author Edition',
#  '1st edition Narrativa',
#  'First Aladdin Edition ',
#  '1st S&S ed.',
#  'First ',
#  'First Scholastic Edition',
#  '1st Hardcover Edition',
#  '1st ',
#  'First English',
#  'First Ballantine Books Edition',
#  '31st Impression',
#  'First Perennial Classics Edition',
#  '1st US',
#  '21st edition',
#  'First Edition: November 2015 edition',
#  '1st Edition, USA',
#  'First U.S. Edition',
#  'First Ecco Edition',
#  '1st Simon Pulse hardcover ed.',
#  '1st Harper Collins Mass Market Paperback Edition',
#  'First Printing',
#  'First Mass Market Domestic Edition',
#  '1st. Edition',
#  'First United States Edition',
#  'First Fourth Estate paperback edition (US)',
#  'The 21st-Century Edition',
#  'First Perseid Publishing Kindle Edition',
#  'Canadian First Edition',
#  '1st Magic Carpet Books edition',
#  '1st Scholastic Edition',
#  'First TOR Edition',
#  'First U.S. Paperback Edition',
#  'First Edition ',
#  'First Edition (U.K.)',
#  'First Edition (U.S.)',
#  '1st U.S. ed.',
#  '1st American Edition',
#  'First Atria Books hardcover edition',
#  'First Vintage Books Edition',
#  'First mass market UK edition',
#  'First Princeton/Bollingen paperback printing',
#  'first edition',
#  'first published 2014',
#  'First American',
#  'First-time author notes',
#  'First Anchor Books Edition',
#  'First/Book Club',
#  'First Edition Hardcover with dust jacket',
#  'First Vista Edition',
#  'First Print',
#  'First  Edition, Large Print',
#  'First Print Edition With Maps and Illustrations',
#  'First Edition - Discontinued',
#  '1st Vintage International Edition',
#  'Seventh Reprint (Booket 1st edition 2009)',
#  'First HarperPerennial Edition',
#  '1st Anchor Books ed',
#  'Trade First Edition',
#  '1st Edtion',
#  'First English Edition',
#  'First Tor Paperback Edition',
#  '1st Aladdin hardcover ed.',
#  'First hardcover edition',
#  'First Vintage International',
#  '61st Edition',
#  '1st Paperback Printing',
#  '1st edition El Mamifero Parlante. Serie mayor',
#  'First paperback edition, 2001',
#  '1st edition Meridian: Crossing Aesthetics',
#  '1st edition Biblioteca Eduardo Galeano',
#  '1st Edition, Media-Tie',
#  '1st ed.',
#  'First Ecco edition',
#  '1st American',
#  '1st Vintage Books Edition',
#  'First Soho Press edition',
#  'First American Edition, US/CAN',
#  '1st edition The Body, in Theory: Histories of Cultural Materialism',
#  'First edition. 文庫',
#  'First Holt Paperbacks Edition',
#  'First Signet Classic Printing (Tilton Introduction)',
#  'First Vintage Book paperback',
#  '1st paper',
#  '1st edition Anthropology',
#  '1st edition Serie bianca',
#  'First US edition',
#  '1st ed',
#  'First UK mass market edition',
#  'First Picador Edition',
#  'First UK edition',
#  '1st UK',
#  'First Movie Tie-In Paperback Edition',
#  '1st Paperback Edition',
#  'First Mass Market Printing, 1997',
#  'First Plume Printing',
#  'First Simon & Schuster hardcover edition']

# %%
#Manually identifying which  editions were misclassified as first
remove_first = ['2000 Reprint (1st edition in Penguin 1945)', '31st Impression', '21st edition', 'The 21st-Century Edition', 'Seventh Reprint (Booket 1st edition 2009)', '61st Edition', 'First Movie Tie-In Paperback Edition']

#Remove above misclassified first editions from the first edition list
for ele in remove_first:
    first.remove(ele)

# %%
#Input 1 if book is a first edition from the list or 0 if it isn't
books.edition.replace(first, 1, inplace=True)
books.loc[books.edition!=1, 'edition'] = 0

# %%
#Rename 'edition' column to 'first_ed' for better readability
books.rename(mapper={'edition':'first_ed'}, inplace=True)

# %% [markdown]
# ### Book Description <a name='desc'></a>
# Because I'm currently not exploring the book description texts, I'll remove it but not before I encode whether it exists for the book or not. This way, I don't completely lose the data.

# %%
#Input 0 for 'Missing' in 'desc' feature or 1 if there's text
books.loc[books.desc=='Missing', 'missing_desc'] = 0
books.loc[books.desc!=0, 'missing_desc'] = 1

# %% [markdown]
# # 3. Adding Categories <a name='categories'></a>
#
# In order to deal with some of the feature data a little easier, I'll be binning some of them into categories.
#
# ## 3.1 Book Length <a name='length'></a>
# It wouldn't make too much sense to input a mean into all the books with 0 pages, and there are too many of them to individually check their book pages. In order to not skew the data with so many incorrect 0-page books, I'll be categorizing the books into `1` (short), `2` (medium), `3` (long) based on the number of pages, while maintaining the 0 page books as `0`. Since some of the books have a disproportionate large number of pages, I'll be breaking it down by the quartiles, with a large portion devoted to the medium range.

# %%
books.pages.describe()
# Out:
# count    38416.000000
# mean       342.581346
# std        244.489347
# min          0.000000
# 25%        226.000000
# 50%        320.000000
# 75%        404.000000
# max      14777.000000
# Name: pages, dtype: float64

# %%
#Calculate the 25th and 75th percentiles as the upper and lower bound for 1 (short) and 2 (long), respectively
short = np.percentile(books.pages, 25)
long = np.percentile(books.pages, 75)

#Categorize each book based on its number of pages, and save it into the 'length feature'
books.loc[(books.pages == 0), 'length'] = 0
books.loc[((books.pages <= short) & (books.pages != 0)), 'length'] = 1
books.loc[(books.pages >= long), 'length'] = 3
#Fill the rest with 2 (medium)
books.length.fillna(2, inplace=True)

# %%
#Convert length feature as categorical
books['length'] = books['length'].astype('category')

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38416 entries, 0 to 38415
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   authors       38416 non-null  object
#  1   desc          38416 non-null  object
#  2   edition       38416 non-null  object
#  3   format        38416 non-null  object
#  4   pages         38416 non-null  float64
#  5   rating        38416 non-null  float64
#  6   rating_count  38416 non-null  int64
#  7   review_count  38416 non-null  int64
#  8   title         38416 non-null  object
#  9   genres        38416 non-null  object
#  10  missing_ed    38416 non-null  float64
#  11  missing_desc  38416 non-null  float64
#  12  length        38416 non-null  category
# dtypes: category(1), float64(4), int64(2), object(6)
# memory usage: 3.8+ MB

# %%
books.length.value_counts()
# Out:
# 2.0    19142
# 3.0     9645
# 1.0     9522
# 0.0      107
# Name: length, dtype: int64

# %% [markdown]
# ## 3.2 Good or Bad Book <a name='goodbad'></a>
#
# Since the data seems relatively ready, I'll be adding my main feature that will be my dependent variable, whether a book is good or bad. This dataset is already curated from the Goodreads' "Best Books List" so there is no reason to believe *any* of the books on this list are relatively bad. Additionally, I admit that opinions of books are subjective; a book can be good for one person, and also bad for another. Moreover, books couldn't really be described as completely black and white, either 'good' or 'bad'.
#
# With all that said, I will be forming two best books list: one in the order of the dataset, determined by the voters of Goodreads; and another based purely on the books' ratings. These will differ only in their initial order, and will be split evenly in half; the first half will  be categorized as 'good' while the second will be the 'bad' ones.

# %%
books.rating.describe()
# Out:
# count    38416.000000
# mean         3.991046
# std          0.275888
# min          2.090000
# 25%          3.820000
# 50%          4.010000
# 75%          4.180000
# max          4.890000
# Name: rating, dtype: float64

# %%
books.head()
# Out:
#                                      authors  \
# 0                 J.K. Rowling|Mary GrandPré
# 1                              Douglas Adams
# 2                           Shel Silverstein
# 3                                  Dan Brown
# 4  Lewis Carroll|John Tenniel|Martin Gardner
#
#                                                 desc edition     format  \
# 0  There is a door at the end of a silent corrido...       0  Paperback
# 1  Seconds before the Earth is demolished to make...       0  Paperback
# 2  "Once there was a tree...and she loved a littl...       0  Hardcover
# 3  An ingenious code hidden in the works of Leona...       0  Paperback
# 4  " I can't explain myself, I'm afraid, sir," sa...       0  Paperback
#
#    pages  rating  rating_count  review_count  \
# 0  870.0    4.48       2041594         33264
# 1  193.0    4.21       1155911         23919
# 2   64.0    4.37        789681         15694
# 3  481.0    3.81       1668594         43699
# 4  239.0    4.07        411153          9166
#
#                                                title  \
# 0          Harry Potter and the Order of the Phoenix
# 1               The Hitchhiker's Guide to the Galaxy
# 2                                    The Giving Tree
# 3                                  The Da Vinci Code
# 4  Alice's Adventures in Wonderland & Through the...
#
#                                               genres  missing_ed  \
# 0                        Fantasy|Young Adult|Fiction         0.0
# 1     Science Fiction|Fiction|Humor|Fantasy|Classics         1.0
# 2  Childrens|Childrens|Picture Books|Classics|Fic...         1.0
# 3                           Fiction|Mystery|Thriller         1.0
# 4                 Classics|Fantasy|Fiction|Childrens         1.0
#
#    missing_desc length
# 0           1.0    3.0
# 1           1.0    1.0
# 2           1.0    1.0
# 3           1.0    3.0
# 4           1.0    2.0

# %%
#Split in half and categorize the top half as 1 (good books) and the bottom half as 0 (bad books)
half = len(books)/2

#Categorize good and bad books
books.loc[:half, 'quality'] = 1
books.loc[half:, 'quality'] = 0

#Make sure the quality feature is a category
books['quality'] = books['quality'].astype('category')

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38416 entries, 0 to 38415
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   authors       38416 non-null  object
#  1   desc          38416 non-null  object
#  2   edition       38416 non-null  object
#  3   format        38416 non-null  object
#  4   pages         38416 non-null  float64
#  5   rating        38416 non-null  float64
#  6   rating_count  38416 non-null  int64
#  7   review_count  38416 non-null  int64
#  8   title         38416 non-null  object
#  9   genres        38416 non-null  object
#  10  missing_ed    38416 non-null  float64
#  11  missing_desc  38416 non-null  float64
#  12  length        38416 non-null  category
#  13  quality       38416 non-null  category
# dtypes: category(2), float64(4), int64(2), object(6)
# memory usage: 5.1+ MB

# %%
books.quality.value_counts()
# Out:
# 1.0    19208
# 0.0    19208
# Name: quality, dtype: int64

# %% [markdown]
# Saving the dataset for later use:

# %%
#Save the dataset
books.to_csv('./data/books.csv')
